# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
IMAGE_SIZE = 256
EPOCHS = 100
BATCH = 32
LR = 1e-4 

PATH = "/kaggle/input/segmentation/data_set/"

# %%
import random

def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "mask/*")))

    # Shuffle the images
    combined = list(zip(images, masks))
    random.shuffle(combined)
    images, masks = zip(*combined)

    total_size = len(images)
    valid_size = int(split * total_size)
    test_size = int(split * total_size)

    train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    return x, y

def tf_dataset(x, y, batch=16):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(PATH)

print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
print("Testing data: ", len(test_x))
# Out:
# Training data:  20286
# Validation data:  2535
# Testing data:  2535

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_y[3]))
imgplot.set_clim(0.0, 1.4)

# %%
def conv_block(inputs, filters, kernel_size, activation, dropout_rate):
#   R = tf.keras.layers.Conv2D(filters, 1, padding='same')(inputs)
  x = tf.keras.layers.Conv2D(filters, kernel_size, padding='same',kernel_regularizer=tf.keras.regularizers.l2(0.01))(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  if activation == 'LeakyReLU':
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
  elif activation == 'sigmoid':
    x = tf.keras.layers.Activation('sigmoid')(x)
#   x = tf.keras.layers.Dropout(dropout_rate)(x)

#   x = tf.keras.layers.Add()([R, x])

  x = tf.keras.layers.Conv2D(filters, kernel_size, padding='same',kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
  x = tf.keras.layers.BatchNormalization()(x)
  if activation == 'LeakyReLU':
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
  elif activation == 'sigmoid':
    x = tf.keras.layers.Activation('sigmoid')(x)
#   x = tf.keras.layers.Dropout(dropout_rate)(x)
  return x

def down_block(inputs, filters, kernel_size, activation,dropout_rate):
  x = conv_block(inputs, filters, kernel_size, activation,dropout_rate)
  x_pool = tf.keras.layers.MaxPooling2D()(x)
  return x, x_pool

def up_block(inputs, skip_input, filters, kernel_size, activation,dropout_rate):
  x = tf.keras.layers.UpSampling2D()(inputs)
  x = tf.keras.layers.Concatenate()([x, skip_input])
  x = conv_block(x, filters, kernel_size, activation,dropout_rate)
  return x

def UNetModel(input_shape=(256, 256, 3)):
  inputs = tf.keras.Input(shape=input_shape, name="input_image")
  # Define the encoder layers
  conv1, pool1 = down_block(inputs, 16, 1, 'LeakyReLU',dropout_rate=0.5)
  conv2, pool2 = down_block(pool1, 32, 5, 'LeakyReLU',dropout_rate=0.5)
  conv3, pool3 = down_block(pool2, 64, 9, 'LeakyReLU',dropout_rate=0.5)
  conv4, pool4 = down_block(pool3, 128, 3, 'LeakyReLU',dropout_rate=0.5)
  conv5, pool5 = down_block(pool4, 256, 7, 'LeakyReLU',dropout_rate=0.5)
  conv6, pool6 = down_block(pool5, 512, 3, 'LeakyReLU',dropout_rate=0.5)

  conv7 = conv_block(pool6, 1024, 3, 'LeakyReLU',dropout_rate=0.5)

  # Define the decoder layers
  up1 = up_block(conv7, conv6, 512, 3, 'LeakyReLU',dropout_rate=0.5)
  up2 = up_block(up1, conv5, 256, 7, 'LeakyReLU',dropout_rate=0.5)
  up3 = up_block(up2, conv4, 128, 3, 'LeakyReLU',dropout_rate=0.5)
  up4 = up_block(up3, conv3, 64, 9, 'LeakyReLU',dropout_rate=0.5)
  up5 = up_block(up4, conv2, 32, 5, 'LeakyReLU',dropout_rate=0.5)
  up6 = up_block(up5, conv1,16, 1, 'LeakyReLU',dropout_rate=0.5)
  
  # Define the output layer
  out = conv_block(up6, 1, 1, 'sigmoid',dropout_rate=0.5)

  # Create the model and return it
  model = tf.keras.Model(inputs=inputs, outputs=out)
  return model

# %%
model = UNetModel()
model.summary()
# Out:
# 2023-01-04 15:13:41.680944: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:41.765020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:41.765882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:41.767139: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-04 15:13:41.767511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:41.768227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:41.768873: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:43.754497: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:43.755359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:43.756038: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:13:43.756627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 64          input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 272         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 12832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 25632       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   165952      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   331840      leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  1605888     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 16, 16, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  3211520     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 16, 16, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 256)    0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 512)    1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 512)    2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 512)    2359808     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 512)    2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 512)    0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 4, 4, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 1024)   9438208     leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 1024)   4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 4, 4, 1024)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 8, 1024)   0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 1536)   0           up_sampling2d[0][0]
#                                                                  leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 512)    2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 512)    2359808     leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 768)  0           up_sampling2d_1[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  9634048     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 16, 16, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 256)  3211520     leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 16, 16, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 384)  0           up_sampling2d_2[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 32, 32, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 128)  147584      leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 32, 32, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0           leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 192)  0           up_sampling2d_3[0][0]
#                                                                  leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   995392      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   331840      leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64) 0           leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 96) 0           up_sampling2d_4[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 76832       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 32) 25632       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 32) 128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 32) 0           leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 48) 0           up_sampling2d_5[0][0]
#                                                                  leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 16) 784         concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 256, 256, 16) 64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 16) 272         leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 16) 64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 1)  17          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 1)  4           conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 1)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 1)  2           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 1)  4           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 1)  0           batch_normalization_27[0][0]
# ==================================================================================================
# Total params: 47,602,187
# Trainable params: 47,590,023
# Non-trainable params: 12,164
# __________________________________________________________________________________________________

# %%
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
def iou_loss(y_true, y_pred):
    y_true = tf.keras.backend.flatten(y_true)
    y_pred = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true * y_pred)
    union = tf.keras.backend.sum(y_true) + tf.keras.backend.sum(y_pred) - intersection
    return 1 - (intersection + 1) / (union + 1)

# %%
delta = 1.0
def HUBER_Loss(y_true, y_pred):
  error = y_true - y_pred
  is_small_error = tf.abs(error) < delta
  squared_loss = tf.square(error) / 2
  linear_loss = delta * tf.abs(error) - delta**2 / 2
  return tf.where(is_small_error, squared_loss, linear_loss)

# %%
def combined_loss(y_true, y_pred):
    combined_loss = dice_loss(y_true, y_pred) + HUBER_Loss(y_true, y_pred) + iou_loss(y_true, y_pred)
    return combined_loss

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [HUBER_Loss,dice_loss,iou_loss,Recall(), Precision()]
model.compile(loss=combined_loss, optimizer=opt, metrics=metrics)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# 2023-01-04 15:13:45.198561: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2023-01-04 15:13:53.731379: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:801] layout failed: Invalid argument: Size of values 0 does not match size of permutation 4 @ fanin shape ingradient_tape/combined_loss/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-01-04 15:13:57.573663: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 634/634 [==============================] - 328s 487ms/step - loss: 9.2615 - HUBER_Loss: 0.0375 - dice_loss: 0.5808 - iou_loss: 0.7346 - recall: 0.4804 - precision: 1.0000 - val_loss: 2.1075 - val_HUBER_Loss: 0.0182 - val_dice_loss: 0.6572 - val_iou_loss: 0.7931 - val_recall: 0.0056 - val_precision: 1.0000
# Epoch 2/100
# 634/634 [==============================] - 291s 459ms/step - loss: 1.7742 - HUBER_Loss: 0.0382 - dice_loss: 0.5728 - iou_loss: 0.7282 - recall: 0.4624 - precision: 1.0000 - val_loss: 1.6931 - val_HUBER_Loss: 0.0224 - val_dice_loss: 0.6036 - val_iou_loss: 0.7526 - val_recall: 0.3646 - val_precision: 1.0000
# Epoch 3/100
# 634/634 [==============================] - 291s 459ms/step - loss: 1.5771 - HUBER_Loss: 0.0397 - dice_loss: 0.5678 - iou_loss: 0.7241 - recall: 0.4696 - precision: 1.0000 - val_loss: 1.7419 - val_HUBER_Loss: 0.0233 - val_dice_loss: 0.7001 - val_iou_loss: 0.8236 - val_recall: 0.0561 - val_precision: 1.0000
# Epoch 4/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.4805 - HUBER_Loss: 0.0408 - dice_loss: 0.5635 - iou_loss: 0.7207 - recall: 0.4674 - precision: 1.0000 - val_loss: 1.4461 - val_HUBER_Loss: 0.0644 - val_dice_loss: 0.5426 - val_iou_loss: 0.7032 - val_recall: 0.4453 - val_precision: 1.0000
# Epoch 5/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.4246 - HUBER_Loss: 0.0417 - dice_loss: 0.5601 - iou_loss: 0.7178 - recall: 0.4653 - precision: 1.0000 - val_loss: 1.4426 - val_HUBER_Loss: 0.0369 - val_dice_loss: 0.5742 - val_iou_loss: 0.7292 - val_recall: 0.2740 - val_precision: 1.0000
# Epoch 6/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.3926 - HUBER_Loss: 0.0424 - dice_loss: 0.5573 - iou_loss: 0.7156 - recall: 0.4646 - precision: 1.0000 - val_loss: 1.4101 - val_HUBER_Loss: 0.0596 - val_dice_loss: 0.5646 - val_iou_loss: 0.7215 - val_recall: 0.7273 - val_precision: 1.0000
# Epoch 7/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.3690 - HUBER_Loss: 0.0427 - dice_loss: 0.5549 - iou_loss: 0.7136 - recall: 0.4608 - precision: 1.0000 - val_loss: 1.4129 - val_HUBER_Loss: 0.0489 - val_dice_loss: 0.5798 - val_iou_loss: 0.7338 - val_recall: 0.7471 - val_precision: 1.0000
# Epoch 8/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.3627 - HUBER_Loss: 0.0436 - dice_loss: 0.5537 - iou_loss: 0.7125 - recall: 0.4588 - precision: 1.0000 - val_loss: 1.4186 - val_HUBER_Loss: 0.0219 - val_dice_loss: 0.6034 - val_iou_loss: 0.7525 - val_recall: 0.4202 - val_precision: 1.0000
# Epoch 9/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.3268 - HUBER_Loss: 0.0409 - dice_loss: 0.5454 - iou_loss: 0.7056 - recall: 0.4565 - precision: 1.0000 - val_loss: 1.4018 - val_HUBER_Loss: 0.0076 - val_dice_loss: 0.6065 - val_iou_loss: 0.7548 - val_recall: 0.2283 - val_precision: 1.0000
# Epoch 10/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.3184 - HUBER_Loss: 0.0400 - dice_loss: 0.5431 - iou_loss: 0.7038 - recall: 0.4563 - precision: 1.0000 - val_loss: 1.3421 - val_HUBER_Loss: 0.0168 - val_dice_loss: 0.5690 - val_iou_loss: 0.7251 - val_recall: 0.3257 - val_precision: 1.0000
# Epoch 11/100
# 634/634 [==============================] - 300s 472ms/step - loss: 1.3134 - HUBER_Loss: 0.0394 - dice_loss: 0.5417 - iou_loss: 0.7025 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.3285 - val_HUBER_Loss: 0.0200 - val_dice_loss: 0.5606 - val_iou_loss: 0.7182 - val_recall: 0.3472 - val_precision: 1.0000
# Epoch 12/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.3094 - HUBER_Loss: 0.0389 - dice_loss: 0.5406 - iou_loss: 0.7016 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.3229 - val_HUBER_Loss: 0.0211 - val_dice_loss: 0.5576 - val_iou_loss: 0.7157 - val_recall: 0.3642 - val_precision: 1.0000
# Epoch 13/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.3062 - HUBER_Loss: 0.0385 - dice_loss: 0.5396 - iou_loss: 0.7008 - recall: 0.4571 - precision: 1.0000 - val_loss: 1.3154 - val_HUBER_Loss: 0.0269 - val_dice_loss: 0.5510 - val_iou_loss: 0.7103 - val_recall: 0.4179 - val_precision: 1.0000
# Epoch 14/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.3034 - HUBER_Loss: 0.0382 - dice_loss: 0.5389 - iou_loss: 0.7002 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.3116 - val_HUBER_Loss: 0.0291 - val_dice_loss: 0.5483 - val_iou_loss: 0.7080 - val_recall: 0.4291 - val_precision: 1.0000
# Epoch 15/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.3010 - HUBER_Loss: 0.0380 - dice_loss: 0.5383 - iou_loss: 0.6997 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.3032 - val_HUBER_Loss: 0.0312 - val_dice_loss: 0.5432 - val_iou_loss: 0.7037 - val_recall: 0.4304 - val_precision: 1.0000
# Epoch 16/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2989 - HUBER_Loss: 0.0378 - dice_loss: 0.5378 - iou_loss: 0.6992 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.3037 - val_HUBER_Loss: 0.0328 - val_dice_loss: 0.5431 - val_iou_loss: 0.7037 - val_recall: 0.4502 - val_precision: 1.0000
# Epoch 17/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2969 - HUBER_Loss: 0.0376 - dice_loss: 0.5374 - iou_loss: 0.6989 - recall: 0.4556 - precision: 1.0000 - val_loss: 1.3035 - val_HUBER_Loss: 0.0285 - val_dice_loss: 0.5457 - val_iou_loss: 0.7059 - val_recall: 0.4203 - val_precision: 1.0000
# Epoch 18/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2938 - HUBER_Loss: 0.0371 - dice_loss: 0.5362 - iou_loss: 0.6979 - recall: 0.4558 - precision: 1.0000 - val_loss: 1.2955 - val_HUBER_Loss: 0.0351 - val_dice_loss: 0.5381 - val_iou_loss: 0.6994 - val_recall: 0.4535 - val_precision: 1.0000
# Epoch 19/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2927 - HUBER_Loss: 0.0370 - dice_loss: 0.5359 - iou_loss: 0.6976 - recall: 0.4563 - precision: 1.0000 - val_loss: 1.2945 - val_HUBER_Loss: 0.0357 - val_dice_loss: 0.5373 - val_iou_loss: 0.6988 - val_recall: 0.4567 - val_precision: 1.0000
# Epoch 20/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.2921 - HUBER_Loss: 0.0369 - dice_loss: 0.5357 - iou_loss: 0.6975 - recall: 0.4564 - precision: 1.0000 - val_loss: 1.2940 - val_HUBER_Loss: 0.0361 - val_dice_loss: 0.5370 - val_iou_loss: 0.6985 - val_recall: 0.4594 - val_precision: 1.0000
# Epoch 21/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2915 - HUBER_Loss: 0.0368 - dice_loss: 0.5356 - iou_loss: 0.6974 - recall: 0.4565 - precision: 1.0000 - val_loss: 1.2934 - val_HUBER_Loss: 0.0365 - val_dice_loss: 0.5366 - val_iou_loss: 0.6982 - val_recall: 0.4619 - val_precision: 1.0000
# Epoch 22/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.2910 - HUBER_Loss: 0.0368 - dice_loss: 0.5354 - iou_loss: 0.6973 - recall: 0.4566 - precision: 1.0000 - val_loss: 1.2925 - val_HUBER_Loss: 0.0368 - val_dice_loss: 0.5360 - val_iou_loss: 0.6977 - val_recall: 0.4633 - val_precision: 1.0000
# Epoch 23/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2905 - HUBER_Loss: 0.0367 - dice_loss: 0.5353 - iou_loss: 0.6971 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.2918 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5355 - val_iou_loss: 0.6972 - val_recall: 0.4661 - val_precision: 1.0000
# Epoch 24/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2900 - HUBER_Loss: 0.0367 - dice_loss: 0.5352 - iou_loss: 0.6970 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.2916 - val_HUBER_Loss: 0.0377 - val_dice_loss: 0.5352 - val_iou_loss: 0.6970 - val_recall: 0.4694 - val_precision: 1.0000
# Epoch 25/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2896 - HUBER_Loss: 0.0366 - dice_loss: 0.5351 - iou_loss: 0.6969 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.2912 - val_HUBER_Loss: 0.0376 - val_dice_loss: 0.5352 - val_iou_loss: 0.6970 - val_recall: 0.4678 - val_precision: 1.0000
# Epoch 26/100
# 634/634 [==============================] - 291s 458ms/step - loss: 1.2891 - HUBER_Loss: 0.0366 - dice_loss: 0.5350 - iou_loss: 0.6968 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.2914 - val_HUBER_Loss: 0.0383 - val_dice_loss: 0.5351 - val_iou_loss: 0.6969 - val_recall: 0.4745 - val_precision: 1.0000
# Epoch 27/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2887 - HUBER_Loss: 0.0365 - dice_loss: 0.5349 - iou_loss: 0.6968 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2911 - val_HUBER_Loss: 0.0382 - val_dice_loss: 0.5350 - val_iou_loss: 0.6968 - val_recall: 0.4747 - val_precision: 1.0000
# Epoch 28/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2882 - HUBER_Loss: 0.0365 - dice_loss: 0.5348 - iou_loss: 0.6967 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2913 - val_HUBER_Loss: 0.0387 - val_dice_loss: 0.5350 - val_iou_loss: 0.6968 - val_recall: 0.4798 - val_precision: 1.0000
# Epoch 29/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.2878 - HUBER_Loss: 0.0364 - dice_loss: 0.5347 - iou_loss: 0.6966 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2912 - val_HUBER_Loss: 0.0403 - val_dice_loss: 0.5342 - val_iou_loss: 0.6961 - val_recall: 0.4916 - val_precision: 1.0000
# Epoch 30/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.2873 - HUBER_Loss: 0.0363 - dice_loss: 0.5345 - iou_loss: 0.6964 - recall: 0.4570 - precision: 1.0000 - val_loss: 1.2867 - val_HUBER_Loss: 0.0378 - val_dice_loss: 0.5331 - val_iou_loss: 0.6952 - val_recall: 0.4630 - val_precision: 1.0000
# Epoch 31/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2872 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6964 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.2865 - val_HUBER_Loss: 0.0382 - val_dice_loss: 0.5328 - val_iou_loss: 0.6950 - val_recall: 0.4647 - val_precision: 1.0000
# Epoch 32/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2871 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6964 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.2865 - val_HUBER_Loss: 0.0383 - val_dice_loss: 0.5327 - val_iou_loss: 0.6949 - val_recall: 0.4655 - val_precision: 1.0000
# Epoch 33/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2870 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6964 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.2865 - val_HUBER_Loss: 0.0384 - val_dice_loss: 0.5327 - val_iou_loss: 0.6949 - val_recall: 0.4660 - val_precision: 1.0000
# Epoch 34/100
# 634/634 [==============================] - 288s 455ms/step - loss: 1.2870 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2871 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6957 - val_recall: 0.4627 - val_precision: 1.0000
# Epoch 35/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.2870 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4569 - precision: 1.0000 - val_loss: 1.2871 - val_HUBER_Loss: 0.0374 - val_dice_loss: 0.5336 - val_iou_loss: 0.6956 - val_recall: 0.4631 - val_precision: 1.0000
# Epoch 36/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4567 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4632 - val_precision: 1.0000
# Epoch 37/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6957 - val_recall: 0.4634 - val_precision: 1.0000
# Epoch 38/100
# 634/634 [==============================] - 292s 460ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4633 - val_precision: 1.0000
# Epoch 39/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4633 - val_precision: 1.0000
# Epoch 40/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4633 - val_precision: 1.0000
# Epoch 41/100
# 634/634 [==============================] - 290s 457ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4633 - val_precision: 1.0000
# Epoch 42/100
# 634/634 [==============================] - 289s 455ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4633 - val_precision: 1.0000
# Epoch 43/100
# 634/634 [==============================] - 289s 456ms/step - loss: 1.2869 - HUBER_Loss: 0.0363 - dice_loss: 0.5344 - iou_loss: 0.6963 - recall: 0.4568 - precision: 1.0000 - val_loss: 1.2873 - val_HUBER_Loss: 0.0373 - val_dice_loss: 0.5337 - val_iou_loss: 0.6958 - val_recall: 0.4633 - val_precision: 1.0000

# %%
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1
    
model.evaluate(test_dataset, steps=test_steps)
# Out:
# 80/80 [==============================] - 90s 1s/step - loss: 1.2823 - HUBER_Loss: 0.0368 - dice_loss: 0.5315 - iou_loss: 0.6939 - recall: 0.4613 - precision: 1.0000
# [1.282340168952942,
#  0.03684259206056595,
#  0.5315114855766296,
#  0.6939167976379395,
#  0.46134045720100403,
#  1.0]

# %%
plt.plot(history.history['loss'], label='Training combined loss loss')
plt.plot(history.history['val_loss'], label='Validation combined loss')


plt.legend()
plt.show()

# %%
plt.plot(history.history['dice_loss'], label='dice_loss_while_MSE_Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['iou_loss'], label='iou_loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['HUBER_Loss'], label='HUBER_Loss')
plt.legend()
plt.show()

# %%
model.save('FF.h5')
model.save_weights('FF_W.h5')

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred_grayscale = (y_pred - y_pred.min()) / (y_pred.max() - y_pred.min())
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred_grayscale)
    ]
    image = np.concatenate(all_images, axis=1)
    
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
